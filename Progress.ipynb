# %%
# %load_ext autoreload
# %autoreload 2

# %%
# external imports
import numpy as np
import pandas as pd

# my imports
from Airport_CLC_Calculation import *
from Timeseries_Graphing import *
from Bar_Plotting import *
from Box_Plotting import *

# %% [markdown]
# ## Yearly Timeseries
# ### Variables:
# ### - years = 1950-2022
# ### - elevation def = 1000
# ### - hours = [7, 10, 13, 16]
# ### Saved to:
# ### - Airport_Trends/Timeseries_Graphs/ airport + "_Years_" + str(years[0]) + "_to_" + str(years[-1]) + "_Months_" + listToString(months) + "_Hours_" + listToString(hours) + "_Elevation_Definition_" + str(elevation_def) + "_PDO_Timeseries.pdf"
# ### - Airport_Trends/PDO_Timeseries_Graphs/ airport + "_Years_" + str(years[0]) + "_to_" + str(years[-1]) + "_Months_" + listToString(months) + "_Hours_" + listToString(hours) + "_Elevation_Definition_" + str(elevation_def) + "_Timeseries.pdf"

# %%
# Timeseries by month

years = range(1950, 2023)
hours = [7, 10, 13, 16]
elevation_def = 1000

months = ["April"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["May"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["June"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["July"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["August"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["September"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["October"]
Timeseries_Graphing(years, months, hours, elevation_def)

# Timeseries by season

months = ["May", "June", "July", "August", "September"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["April", "May", "June", "July", "August", "September", "October"]
Timeseries_Graphing(years, months, hours, elevation_def)

# %% [markdown]
# ## Summary Barplot
# ### Variables:
# ### - years = 1950-2022
# ### - elevation def = 1000
# ### - hours = [7, 10, 13, 16]
# ### - sort_by = "latitude"
# ### Saved to:
# ### - Airport_Trends/Bar_Plots/ "Bar_Plot_Summary_" + "Months_" + listToString(months) + "_Hours_" + listToString(hours) + "_Elevation_Definition_" + str(elevation_def) + "_Sorted_By_" + sort_by

# %%
# Barplot by month

years = range(1950, 2023)
hours = [7, 10, 13, 16]
elevation_def = 1000
sort_by = "latitude"

months = ["April"]
bar_plotting(years, months, hours, elevation_def, sort_by)

months = ["May"]
bar_plotting(years, months, hours, elevation_def, sort_by)

months = ["June"]
bar_plotting(years, months, hours, elevation_def, sort_by)

months = ["July"]
bar_plotting(years, months, hours, elevation_def, sort_by)

months = ["August"]
bar_plotting(years, months, hours, elevation_def, sort_by)

months = ["September"]
bar_plotting(years, months, hours, elevation_def, sort_by)

months = ["October"]
bar_plotting(years, months, hours, elevation_def, sort_by)

# Barplot by season

months = ["May", "June", "July", "August", "September"]
bar_plotting(years, months, hours, elevation_def, sort_by)

months = ["April", "May", "June", "July", "August", "September", "October"]
bar_plotting(years, months, hours, elevation_def, sort_by)

# %% [markdown]
# ## Era Boxplot
# ### Variables:
# ### - years = 1950-2022
# ### - elevation def = 1000
# ### - hours = [7, 10, 13, 16]
# ### - edge_length = 30
# ### Saved to:
# ### - "Airport_Trends/Box_Plots/" + "Box_Plot_First_vs._Last_" + str(edge_length) + "_Years\n" + airport + "Months_" + listToString(months) + "_Hours_" + listToString(hours) + "_Elevation_Definition_" + str(elevation_def) + '.pdf'

# %%
# Boxplot by month

hours = [7, 10, 13, 16]
elevation_def = 1000
sort_by = "latitude"
edge_length = 30

months = ["April"]
box_plotting_edge(months, hours, elevation_def, edge_length)

months = ["May"]
box_plotting_edge(months, hours, elevation_def, edge_length)

months = ["June"]
box_plotting_edge(months, hours, elevation_def, edge_length)

months = ["July"]
box_plotting_edge(months, hours, elevation_def, edge_length)

months = ["August"]
box_plotting_edge(months, hours, elevation_def, edge_length)

months = ["September"]
box_plotting_edge(months, hours, elevation_def, edge_length)

months = ["October"]
box_plotting_edge(months, hours, elevation_def, edge_length)

# Boxplot by season

months = ["May", "June", "July", "August", "September"]
box_plotting_edge(months, hours, elevation_def, edge_length)

months = ["April", "May", "June", "July", "August", "September", "October"]
box_plotting_edge(months, hours, elevation_def, edge_length)

# %% [markdown]
# ## April/May 2023 Update

# %%
years = range(1950, 2024) # added 2023
hours = [7, 10, 13, 16]
elevation_def = 1000

months = ["April"]
Timeseries_Graphing(years, months, hours, elevation_def)
# saved to Airport_Trends/Timeseries_Graphs/ airport _Years_1950_to_2023_Months_April_Hours_7_10_13_16_Elevation_Definition_1000_Timeseries.pdf"

months = ["May"]
Timeseries_Graphing(years, months, hours, elevation_def)
# saved to Airport_Trends/Timeseries_Graphs/ airport _Years_1950_to_2023_Months_May_Hours_7_10_13_16_Elevation_Definition_1000_Timeseries.pdf"

months = ["April", "May"]
Timeseries_Graphing(years, months, hours, elevation_def)
# saved to Airport_Trends/Timeseries_Graphs/ airport _Years_1950_to_2023_Months_April_May_Hours_7_10_13_16_Elevation_Definition_1000_Timeseries.pdf"
# Out:
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_graph_df["Avg_CLC"][index] = mean_missing
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_graph_df["Avg_CLC"][index] = mean_missing
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
elevation_def = 1000

months = ["April"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["May"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["April", "May"]
Timeseries_Graphing(years, months, hours, elevation_def)
# Out:
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
years = range(1950, 2024) # added 2023
hours = [7, 10, 13, 16]
elevation_def = 2000

months = ["April"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["May"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["April", "May"]
Timeseries_Graphing(years, months, hours, elevation_def)
# Out:
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_graph_df["Avg_CLC"][index] = mean_missing
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_graph_df["Avg_CLC"][index] = mean_missing
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
years = range(1950, 2024) # added 2023
hours = [7, 10, 13, 16]
elevation_def = 1000

months = ["June"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["April", "May", "June"]
Timeseries_Graphing(years, months, hours, elevation_def)
# Out:
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_graph_df["Avg_CLC"][index] = mean_missing
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_graph_df["Avg_CLC"][index] = mean_missing
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
years = range(1950, 2024) # added 2023
hours = [7, 10, 13, 16]
elevation_def = 2000

months = ["June"]
Timeseries_Graphing(years, months, hours, elevation_def)

months = ["April", "May", "June"]
Timeseries_Graphing(years, months, hours, elevation_def)
# Out:
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_graph_df["Avg_CLC"][index] = mean_missing
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_graph_df["Avg_CLC"][index] = mean_missing
# /Users/ginoangelici/Projects/Scripps/Coastal-Low-Cloudiness/Timeseries_Graphing.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
