# %%
# %load_ext autoreload
# %autoreload

# %%
# external imports
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
import pandas as pd
import pytz
import math
import os
import glob
import scipy.stats
from scipy import stats
import pandas as pd , numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sma
import seaborn as sns

# my imports
from Valid import *
from Airport_CLC_Calculation import *
from Pacificize import *
from Table_Creation import *
from Box_Plotting import *
from Bar_Plotting import *
from Timeseries_Graphing import *
from Tapestry import *
from Table_Creation import *

# %%
# so far we have done:
# timeseries for all 22 airports
# avg clc tables for all 22 airports
# 
#

# %%
# uses folder labeled Merged_Files
# converts given csv of airport data from utc csv to pt dataframe
Pacificize()
# Out:
# Saved 1 airport datasets
# Saved 2 airport datasets
# Saved 3 airport datasets
# Saved 4 airport datasets
# Saved 5 airport datasets
# Saved 6 airport datasets
# Saved 7 airport datasets
# Saved 8 airport datasets
# Saved 9 airport datasets
# Saved 10 airport datasets
# Saved 11 airport datasets
# Saved 12 airport datasets
# Saved 13 airport datasets
# Saved 14 airport datasets
# Saved 15 airport datasets
# Saved 16 airport datasets
# Saved 17 airport datasets
# Saved 18 airport datasets
# Saved 19 airport datasets
# Saved 20 airport datasets
# Saved 21 airport datasets
# Saved 22 airport datasets
# Saved 23 airport datasets
# Saved 24 airport datasets
# Saved 25 airport datasets
# Saved 26 airport datasets
# Saved 27 airport datasets
# Done

# %%
from Table_Creation import *
years = range(1950, 2023)
months = ["April"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)
# Out:
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# ...

# %%
years = range(1950, 2023)

months = ["April", "May", "June", "July", "August", "September", "October"]

hours = [7, 10, 13, 16]

elevation_def = 1000

sort_by = "latitude"

bar_plot = bar_plotting(years, months, hours, elevation_def, sort_by)

# %%
Pacificize()
# Out:
# Saved 1 airport datasets
# Saved 2 airport datasets
# Saved 3 airport datasets
# Saved 4 airport datasets
# Saved 5 airport datasets
# Saved 6 airport datasets
# Saved 7 airport datasets
# Saved 8 airport datasets
# Saved 9 airport datasets
# Saved 10 airport datasets
# Saved 11 airport datasets
# Saved 12 airport datasets
# Saved 13 airport datasets
# Saved 14 airport datasets
# Saved 15 airport datasets
# Saved 16 airport datasets
# Saved 17 airport datasets
# Saved 18 airport datasets
# Saved 19 airport datasets
# Saved 20 airport datasets
# Saved 21 airport datasets
# Saved 22 airport datasets
# Saved 23 airport datasets
# Saved 24 airport datasets
# Saved 25 airport datasets
# Saved 26 airport datasets
# Saved 27 airport datasets
# Done

# %%
years = range(1950, 2024)
months = ["April"]
hours = [7, 10, 13, 16]
elevation_def = 1000
for month in [["April"], ["May"]]:
    Table_Creation(years, months, hours, elevation_def)
# Out:
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# /Users/ginoangelici/Coastal-Low-Cloudiness/Airport_CLC_Calculation.py:75: RuntimeWarning: Mean of empty slice
#   CLC.append(np.nanmean(CLC_percent_by_month))
# ...

# %%
#------------------------------------------------------
years = range(1950, 2023)

months = ["May", "June", "July", "August", "September"]

hours = [7, 10, 13, 16]

elevation_def = 1000

edge_length = 30
#------------------------------------------------------

box_plotting_edge(months, hours, elevation_def, edge_length)
# Out:
# /Users/ginoangelici/Coastal-Low-Cloudiness/Box_Plotting.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   box_data_compare[str(airport) + "_" + month + "\nBefore"] = before
# /Users/ginoangelici/Coastal-Low-Cloudiness/Box_Plotting.py:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   box_data_compare[str(airport) + "_" + month + "\nAfter"] = after
# ...

# %%
#------------------------------------------------------
years = range(1950, 2024)

months = ["April"]

hours = [7, 10, 13, 16]

elevation_def = 1000
#------------------------------------------------------

bar_plotting(years, months, hours, elevation_def, sort_by)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 11
#       8 elevation_def = 1000
#       9 #------------------------------------------------------
# ---> 11 bar_plotting(years, months, hours, elevation_def, sort_by)
#
# File ~/Coastal-Low-Cloudiness/Bar_Plotting.py:55, in bar_plotting(years, months, hours, elevation_def, sort_by)
#      51 details = "Months_" + listToString(months) + "_Hours_" + listToString(hours) + "_Elevation_Definition_" + str(elevation_def) + "_Sorted_By_" + sort_by
#      53 bar_plot_title = "Bar_Plot_Summary_" + details
# ---> 55 bar_plot_data = pd.read_csv("CLC_Data/Value_Tables/Airport_Values_Summary_Table_Years_1950_to_2022_Months_" + listToString(months) + "_Hours_" + listToString(hours) + "_Elevation_Definition_" + str(elevation_def) + ".csv", sep = "\t", usecols=range(1,6), index_col = 'airports')
# ...
