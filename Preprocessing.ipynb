# %%
# %load_ext autoreload
# %autoreload 2

# %%
# external imports
import numpy as np
import pandas as pd

# my imports
from Valid import *
from Airport_CLC_Calculation import *
from Pacificize import *
from Table_Creation import *

# %% [markdown]
# ## Pre-Processing

# %%
# uses folder labeled Merged_Files (data is manually merged)
# converts given csv of airport data from utc csv to pt dataframe
Pacificize()
# Out:
# Saved 1 airport datasets
# Saved 2 airport datasets
# Saved 3 airport datasets
# Saved 4 airport datasets
# Saved 5 airport datasets
# Saved 6 airport datasets
# Saved 7 airport datasets
# Saved 8 airport datasets
# Saved 9 airport datasets
# Saved 10 airport datasets
# Saved 11 airport datasets
# Saved 12 airport datasets
# Saved 13 airport datasets
# Saved 14 airport datasets
# Saved 15 airport datasets
# Saved 16 airport datasets
# Saved 17 airport datasets
# Saved 18 airport datasets
# Saved 19 airport datasets
# Saved 20 airport datasets
# Saved 21 airport datasets
# Saved 22 airport datasets
# Saved 23 airport datasets
# Saved 24 airport datasets
# Saved 25 airport datasets
# Saved 26 airport datasets
# Saved 27 airport datasets
# Done

# %% [markdown]
# ## Table Creation by Year
# ### Variables:
# ### - years = 1950-2022
# ### - elevation def = 1000
# ### - hours = [7, 10, 13, 16]
# ### Saves to
# ### - Airport_Data_Tables/
# ### - CLC_Data/Avg_Tables/
# ### - CLC_Data/Value_Tables/

# %%
# by month

years = range(1950, 2023)
months = ["April"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)

years = range(1950, 2023)
months = ["May"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)

years = range(1950, 2023)
months = ["June"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)

years = range(1950, 2023)
months = ["July"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)

years = range(1950, 2023)
months = ["August"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)

years = range(1950, 2023)
months = ["September"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)

# by season

years = range(1950, 2023)
months = ["May", "June", "July", "August", "September"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)

years = range(1950, 2023)
months = ["April", "May", "June", "July", "August", "September", "October"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)
# Out:
# PADK
# Processed 1 airport datasets
# CYAZ
# Processed 2 airport datasets
# KACV
# Processed 3 airport datasets
# PAHO
# Processed 4 airport datasets
# KLGB
# Processed 5 airport datasets
# KNUC
# Processed 6 airport datasets
# KNTD
# Processed 7 airport datasets
# KNZY
# Processed 8 airport datasets
# PACD
# Processed 9 airport datasets
# PANT
# Processed 10 airport datasets
# KMRY
# Processed 11 airport datasets
# KLAX
# Processed 12 airport datasets
# KAST
# Processed 13 airport datasets
# KSAN
# Processed 14 airport datasets
# KNSI
# Processed 15 airport datasets
# KSFO
# Processed 16 airport datasets
# KSIT
# Processed 17 airport datasets
# PYAK
# Processed 18 airport datasets
# KOAK
# Processed 19 airport datasets
# KOTH
# Processed 20 airport datasets
# PADQ
# Processed 21 airport datasets
# KVBG
# Processed 22 airport datasets
# PADK
# Processed 1 airport datasets
# CYAZ
# Processed 2 airport datasets
# KACV
# Processed 3 airport datasets
# PAHO
# Processed 4 airport datasets
# KLGB
# Processed 5 airport datasets
# KNUC
# Processed 6 airport datasets
# KNTD
# Processed 7 airport datasets
# KNZY
# Processed 8 airport datasets
# PACD
# Processed 9 airport datasets
# PANT
# Processed 10 airport datasets
# KMRY
# Processed 11 airport datasets
# KLAX
# Processed 12 airport datasets
# KAST
# Processed 13 airport datasets
# KSAN
# Processed 14 airport datasets
# KNSI
# Processed 15 airport datasets
# KSFO
# Processed 16 airport datasets
# KSIT
# Processed 17 airport datasets
# PYAK
# Processed 18 airport datasets
# KOAK
# Processed 19 airport datasets
# KOTH
# Processed 20 airport datasets
# PADQ
# Processed 21 airport datasets
# KVBG
# Processed 22 airport datasets
# PADK
# Processed 1 airport datasets
# CYAZ
# Processed 2 airport datasets
# KACV
# Processed 3 airport datasets
# PAHO
# Processed 4 airport datasets
# KLGB
# Processed 5 airport datasets
# KNUC
# Processed 6 airport datasets
# KNTD
# Processed 7 airport datasets
# KNZY
# Processed 8 airport datasets
# PACD
# Processed 9 airport datasets
# PANT
# Processed 10 airport datasets
# KMRY
# Processed 11 airport datasets
# KLAX
# Processed 12 airport datasets
# KAST
# Processed 13 airport datasets
# KSAN
# Processed 14 airport datasets
# KNSI
# Processed 15 airport datasets
# KSFO
# Processed 16 airport datasets
# KSIT
# Processed 17 airport datasets
# PYAK
# Processed 18 airport datasets
# KOAK
# Processed 19 airport datasets
# KOTH
# Processed 20 airport datasets
# PADQ
# Processed 21 airport datasets
# KVBG
# Processed 22 airport datasets
# PADK
# Processed 1 airport datasets
# CYAZ
# Processed 2 airport datasets
# KACV
# Processed 3 airport datasets
# PAHO
# Processed 4 airport datasets
# KLGB
# Processed 5 airport datasets
# KNUC
# Processed 6 airport datasets
# KNTD
# Processed 7 airport datasets
# KNZY
# Processed 8 airport datasets
# PACD
# Processed 9 airport datasets
# PANT
# Processed 10 airport datasets
# KMRY
# Processed 11 airport datasets
# KLAX
# Processed 12 airport datasets
# KAST
# Processed 13 airport datasets
# KSAN
# Processed 14 airport datasets
# KNSI
# Processed 15 airport datasets
# KSFO
# Processed 16 airport datasets
# KSIT
# Processed 17 airport datasets
# PYAK
# Processed 18 airport datasets
# KOAK
# Processed 19 airport datasets
# KOTH
# Processed 20 airport datasets
# PADQ
# Processed 21 airport datasets
# KVBG
# Processed 22 airport datasets
# PADK
# Processed 1 airport datasets
# CYAZ
# Processed 2 airport datasets
# KACV
# Processed 3 airport datasets
# PAHO
# Processed 4 airport datasets
# KLGB
# Processed 5 airport datasets
# KNUC
# Processed 6 airport datasets
# KNTD
# Processed 7 airport datasets
# KNZY
# Processed 8 airport datasets
# PACD
# Processed 9 airport datasets
# PANT
# Processed 10 airport datasets
# KMRY
# Processed 11 airport datasets
# KLAX
# Processed 12 airport datasets
# KAST
# Processed 13 airport datasets
# KSAN
# Processed 14 airport datasets
# KNSI
# Processed 15 airport datasets
# KSFO
# Processed 16 airport datasets
# KSIT
# Processed 17 airport datasets
# PYAK
# Processed 18 airport datasets
# KOAK
# Processed 19 airport datasets
# KOTH
# Processed 20 airport datasets
# PADQ
# Processed 21 airport datasets
# KVBG
# Processed 22 airport datasets
# PADK
# Processed 1 airport datasets
# CYAZ
# Processed 2 airport datasets
# KACV
# Processed 3 airport datasets
# PAHO
# Processed 4 airport datasets
# KLGB
# Processed 5 airport datasets
# KNUC
# Processed 6 airport datasets
# KNTD
# Processed 7 airport datasets
# KNZY
# Processed 8 airport datasets
# PACD
# Processed 9 airport datasets
# PANT
# Processed 10 airport datasets
# KMRY
# Processed 11 airport datasets
# KLAX
# Processed 12 airport datasets
# KAST
# Processed 13 airport datasets
# KSAN
# Processed 14 airport datasets
# KNSI
# Processed 15 airport datasets
# KSFO
# Processed 16 airport datasets
# KSIT
# Processed 17 airport datasets
# PYAK
# Processed 18 airport datasets
# KOAK
# Processed 19 airport datasets
# KOTH
# Processed 20 airport datasets
# PADQ
# Processed 21 airport datasets
# KVBG
# Processed 22 airport datasets
# PADK
# Processed 1 airport datasets
# CYAZ
# Processed 2 airport datasets
# KACV
# Processed 3 airport datasets
# PAHO
# Processed 4 airport datasets
# KLGB
# Processed 5 airport datasets
# KNUC
# Processed 6 airport datasets
# KNTD
# Processed 7 airport datasets
# KNZY
# Processed 8 airport datasets
# PACD
# Processed 9 airport datasets
# PANT
# Processed 10 airport datasets
# KMRY
# Processed 11 airport datasets
# KLAX
# Processed 12 airport datasets
# KAST
# Processed 13 airport datasets
# KSAN
# Processed 14 airport datasets
# KNSI
# Processed 15 airport datasets
# KSFO
# Processed 16 airport datasets
# KSIT
# Processed 17 airport datasets
# PYAK
# Processed 18 airport datasets
# KOAK
# Processed 19 airport datasets
# KOTH
# Processed 20 airport datasets
# PADQ
# Processed 21 airport datasets
# KVBG
# Processed 22 airport datasets
# PADK
# Processed 1 airport datasets
# CYAZ
# Processed 2 airport datasets
# KACV
# Processed 3 airport datasets
# PAHO
# Processed 4 airport datasets
# KLGB
# Processed 5 airport datasets
# KNUC
# Processed 6 airport datasets
# KNTD
# Processed 7 airport datasets
# KNZY
# Processed 8 airport datasets
# PACD
# Processed 9 airport datasets
# PANT
# Processed 10 airport datasets
# KMRY
# Processed 11 airport datasets
# KLAX
# Processed 12 airport datasets
# KAST
# Processed 13 airport datasets
# KSAN
# Processed 14 airport datasets
# KNSI
# Processed 15 airport datasets
# KSFO
# Processed 16 airport datasets
# KSIT
# Processed 17 airport datasets
# PYAK
# Processed 18 airport datasets
# KOAK
# Processed 19 airport datasets
# KOTH
# Processed 20 airport datasets
# PADQ
# Processed 21 airport datasets
# KVBG
# Processed 22 airport datasets

# %% [markdown]
# ## Table Creation by Era
# ### Variables:
# ### - years = 1950-2022
# ### - elevation def = 1000
# ### - era_length = 30
# ### Saves to
# ### - Airport_Data_Tables/
# ### - CLC_Data/Avg_Tables/
# ### - CLC_Data/Value_Tables/

# %%
# by month

years = range(1950, 2023)
months = ["April"]
hours = [7, 10, 13, 16]
elevation_def = 1000
era_length = 30
Table_Creation_Era(years, months, hours, elevation_def, era_length)

years = range(1950, 2023)
months = ["May"]
hours = [7, 10, 13, 16]
elevation_def = 1000
era_length = 30
Table_Creation_Era(years, months, hours, elevation_def, era_length)

years = range(1950, 2023)
months = ["June"]
hours = [7, 10, 13, 16]
elevation_def = 1000
era_length = 30
Table_Creation_Era(years, months, hours, elevation_def, era_length)

years = range(1950, 2023)
months = ["July"]
hours = [7, 10, 13, 16]
elevation_def = 1000
era_length = 30
Table_Creation_Era(years, months, hours, elevation_def, era_length)

years = range(1950, 2023)
months = ["August"]
hours = [7, 10, 13, 16]
elevation_def = 1000
era_length = 30
Table_Creation_Era(years, months, hours, elevation_def, era_length)

years = range(1950, 2023)
months = ["September"]
hours = [7, 10, 13, 16]
elevation_def = 1000
era_length = 30
Table_Creation_Era(years, months, hours, elevation_def, era_length)

years = range(1950, 2023)
months = ["October"]
hours = [7, 10, 13, 16]
elevation_def = 1000
era_length = 30
Table_Creation_Era(years, months, hours, elevation_def, era_length)

# by season

years = range(1950, 2023)
months = ["May", "June", "July", "August", "September"]
hours = [7, 10, 13, 16]
elevation_def = 1000
era_length = 30
Table_Creation_Era(years, months, hours, elevation_def, era_length)

years = range(1950, 2023)
months = ["April", "May", "June", "July", "August", "September", "October"]
hours = [7, 10, 13, 16]
elevation_def = 1000
era_length = 30
Table_Creation_Era(years, months, hours, elevation_def, era_length)
# Out:
# Processed 1 dataset eras
# [0000000000000000000000000000000000000000000]
# Processed 2 dataset eras
# [1000000000000000000000000000000000000000000]
# Processed 3 dataset eras
# [1100000000000000000000000000000000000000000]
# Processed 4 dataset eras
# [1110000000000000000000000000000000000000000]
# Processed 5 dataset eras
# [1111000000000000000000000000000000000000000]
# Processed 6 dataset eras
# [1111100000000000000000000000000000000000000]
# Processed 7 dataset eras
# [1111110000000000000000000000000000000000000]
# Processed 8 dataset eras
# [1111111000000000000000000000000000000000000]
# Processed 9 dataset eras
# [1111111100000000000000000000000000000000000]
# Processed 10 dataset eras
# [1111111110000000000000000000000000000000000]
# Processed 11 dataset eras
# [1111111111000000000000000000000000000000000]
# Processed 12 dataset eras
# [1111111111100000000000000000000000000000000]
# Processed 13 dataset eras
# [1111111111110000000000000000000000000000000]
# Processed 14 dataset eras
# [1111111111111000000000000000000000000000000]
# Processed 15 dataset eras
# [1111111111111100000000000000000000000000000]
# Processed 16 dataset eras
# [1111111111111110000000000000000000000000000]
# Processed 17 dataset eras
# [1111111111111111000000000000000000000000000]
# Processed 18 dataset eras
# [1111111111111111100000000000000000000000000]
# Processed 19 dataset eras
# [1111111111111111110000000000000000000000000]
# Processed 20 dataset eras
# [1111111111111111111000000000000000000000000]
# Processed 21 dataset eras
# [1111111111111111111100000000000000000000000]
# Processed 22 dataset eras
# [1111111111111111111110000000000000000000000]
# Processed 23 dataset eras
# [1111111111111111111111000000000000000000000]
# Processed 24 dataset eras
# [1111111111111111111111100000000000000000000]
# Processed 25 dataset eras
# [1111111111111111111111110000000000000000000]
# Processed 26 dataset eras
# [1111111111111111111111111000000000000000000]
# Processed 27 dataset eras
# [1111111111111111111111111100000000000000000]
# Processed 28 dataset eras
# [1111111111111111111111111110000000000000000]
# Processed 29 dataset eras
# [1111111111111111111111111111000000000000000]
# Processed 30 dataset eras
# [1111111111111111111111111111100000000000000]
# Processed 31 dataset eras
# [1111111111111111111111111111110000000000000]
# Processed 32 dataset eras
# [1111111111111111111111111111111000000000000]
# Processed 33 dataset eras
# [1111111111111111111111111111111100000000000]
# Processed 34 dataset eras
# [1111111111111111111111111111111110000000000]
# Processed 35 dataset eras
# [1111111111111111111111111111111111000000000]
# Processed 36 dataset eras
# [1111111111111111111111111111111111100000000]
# Processed 37 dataset eras
# [1111111111111111111111111111111111110000000]
# Processed 38 dataset eras
# [1111111111111111111111111111111111111000000]
# Processed 39 dataset eras
# [1111111111111111111111111111111111111100000]
# Processed 40 dataset eras
# [1111111111111111111111111111111111111110000]
# Processed 41 dataset eras
# [1111111111111111111111111111111111111111000]
# Processed 42 dataset eras
# [1111111111111111111111111111111111111111100]
# Processed 43 dataset eras
# [1111111111111111111111111111111111111111110]
# Processed 44 dataset eras
# [1111111111111111111111111111111111111111111]
# Processed 1 dataset eras
# [0000000000000000000000000000000000000000000]
# Processed 2 dataset eras
# [1000000000000000000000000000000000000000000]
# Processed 3 dataset eras
# [1100000000000000000000000000000000000000000]
# Processed 4 dataset eras
# [1110000000000000000000000000000000000000000]
# Processed 5 dataset eras
# [1111000000000000000000000000000000000000000]
# Processed 6 dataset eras
# [1111100000000000000000000000000000000000000]
# Processed 7 dataset eras
# [1111110000000000000000000000000000000000000]
# Processed 8 dataset eras
# [1111111000000000000000000000000000000000000]
# Processed 9 dataset eras
# [1111111100000000000000000000000000000000000]
# Processed 10 dataset eras
# [1111111110000000000000000000000000000000000]
# Processed 11 dataset eras
# [1111111111000000000000000000000000000000000]
# Processed 12 dataset eras
# [1111111111100000000000000000000000000000000]
# Processed 13 dataset eras
# [1111111111110000000000000000000000000000000]
# Processed 14 dataset eras
# [1111111111111000000000000000000000000000000]
# Processed 15 dataset eras
# [1111111111111100000000000000000000000000000]
# Processed 16 dataset eras
# [1111111111111110000000000000000000000000000]
# Processed 17 dataset eras
# [1111111111111111000000000000000000000000000]
# Processed 18 dataset eras
# [1111111111111111100000000000000000000000000]
# Processed 19 dataset eras
# [1111111111111111110000000000000000000000000]
# Processed 20 dataset eras
# [1111111111111111111000000000000000000000000]
# Processed 21 dataset eras
# [1111111111111111111100000000000000000000000]
# Processed 22 dataset eras
# [1111111111111111111110000000000000000000000]
# Processed 23 dataset eras
# [1111111111111111111111000000000000000000000]
# Processed 24 dataset eras
# [1111111111111111111111100000000000000000000]
# Processed 25 dataset eras
# [1111111111111111111111110000000000000000000]
# Processed 26 dataset eras
# [1111111111111111111111111000000000000000000]
# Processed 27 dataset eras
# [1111111111111111111111111100000000000000000]
# Processed 28 dataset eras
# [1111111111111111111111111110000000000000000]
# Processed 29 dataset eras
# [1111111111111111111111111111000000000000000]
# Processed 30 dataset eras
# [1111111111111111111111111111100000000000000]
# Processed 31 dataset eras
# [1111111111111111111111111111110000000000000]
# Processed 32 dataset eras
# [1111111111111111111111111111111000000000000]
# Processed 33 dataset eras
# [1111111111111111111111111111111100000000000]
# Processed 34 dataset eras
# [1111111111111111111111111111111110000000000]
# Processed 35 dataset eras
# [1111111111111111111111111111111111000000000]
# Processed 36 dataset eras
# [1111111111111111111111111111111111100000000]
# Processed 37 dataset eras
# [1111111111111111111111111111111111110000000]
# Processed 38 dataset eras
# [1111111111111111111111111111111111111000000]
# Processed 39 dataset eras
# [1111111111111111111111111111111111111100000]
# Processed 40 dataset eras
# [1111111111111111111111111111111111111110000]
# Processed 41 dataset eras
# [1111111111111111111111111111111111111111000]
# Processed 42 dataset eras
# [1111111111111111111111111111111111111111100]
# Processed 43 dataset eras
# [1111111111111111111111111111111111111111110]
# Processed 44 dataset eras
# [1111111111111111111111111111111111111111111]
# Processed 1 dataset eras
# [0000000000000000000000000000000000000000000]
# Processed 2 dataset eras
# [1000000000000000000000000000000000000000000]
# Processed 3 dataset eras
# [1100000000000000000000000000000000000000000]
# Processed 4 dataset eras
# [1110000000000000000000000000000000000000000]
# Processed 5 dataset eras
# [1111000000000000000000000000000000000000000]
# Processed 6 dataset eras
# [1111100000000000000000000000000000000000000]
# Processed 7 dataset eras
# [1111110000000000000000000000000000000000000]
# Processed 8 dataset eras
# [1111111000000000000000000000000000000000000]
# Processed 9 dataset eras
# [1111111100000000000000000000000000000000000]
# Processed 10 dataset eras
# [1111111110000000000000000000000000000000000]
# Processed 11 dataset eras
# [1111111111000000000000000000000000000000000]
# Processed 12 dataset eras
# [1111111111100000000000000000000000000000000]
# Processed 13 dataset eras
# [1111111111110000000000000000000000000000000]
# Processed 14 dataset eras
# [1111111111111000000000000000000000000000000]
# Processed 15 dataset eras
# [1111111111111100000000000000000000000000000]
# Processed 16 dataset eras
# [1111111111111110000000000000000000000000000]
# Processed 17 dataset eras
# [1111111111111111000000000000000000000000000]
# Processed 18 dataset eras
# [1111111111111111100000000000000000000000000]
# Processed 19 dataset eras
# [1111111111111111110000000000000000000000000]
# Processed 20 dataset eras
# [1111111111111111111000000000000000000000000]
# Processed 21 dataset eras
# [1111111111111111111100000000000000000000000]
# Processed 22 dataset eras
# [1111111111111111111110000000000000000000000]
# Processed 23 dataset eras
# [1111111111111111111111000000000000000000000]
# Processed 24 dataset eras
# [1111111111111111111111100000000000000000000]
# Processed 25 dataset eras
# [1111111111111111111111110000000000000000000]
# Processed 26 dataset eras
# [1111111111111111111111111000000000000000000]
# Processed 27 dataset eras
# [1111111111111111111111111100000000000000000]
# Processed 28 dataset eras
# [1111111111111111111111111110000000000000000]
# Processed 29 dataset eras
# [1111111111111111111111111111000000000000000]
# Processed 30 dataset eras
# [1111111111111111111111111111100000000000000]
# Processed 31 dataset eras
# [1111111111111111111111111111110000000000000]
# Processed 32 dataset eras
# [1111111111111111111111111111111000000000000]
# Processed 33 dataset eras
# [1111111111111111111111111111111100000000000]
# Processed 34 dataset eras
# [1111111111111111111111111111111110000000000]
# Processed 35 dataset eras
# [1111111111111111111111111111111111000000000]
# Processed 36 dataset eras
# [1111111111111111111111111111111111100000000]
# Processed 37 dataset eras
# [1111111111111111111111111111111111110000000]
# Processed 38 dataset eras
# [1111111111111111111111111111111111111000000]
# Processed 39 dataset eras
# [1111111111111111111111111111111111111100000]
# Processed 40 dataset eras
# [1111111111111111111111111111111111111110000]
# Processed 41 dataset eras
# [1111111111111111111111111111111111111111000]
# Processed 42 dataset eras
# [1111111111111111111111111111111111111111100]
# Processed 43 dataset eras
# [1111111111111111111111111111111111111111110]
# Processed 44 dataset eras
# [1111111111111111111111111111111111111111111]
# Processed 1 dataset eras
# [0000000000000000000000000000000000000000000]
# Processed 2 dataset eras
# [1000000000000000000000000000000000000000000]
# Processed 3 dataset eras
# [1100000000000000000000000000000000000000000]
# Processed 4 dataset eras
# [1110000000000000000000000000000000000000000]
# Processed 5 dataset eras
# [1111000000000000000000000000000000000000000]
# Processed 6 dataset eras
# [1111100000000000000000000000000000000000000]
# Processed 7 dataset eras
# [1111110000000000000000000000000000000000000]
# Processed 8 dataset eras
# [1111111000000000000000000000000000000000000]
# Processed 9 dataset eras
# [1111111100000000000000000000000000000000000]
# Processed 10 dataset eras
# [1111111110000000000000000000000000000000000]
# Processed 11 dataset eras
# [1111111111000000000000000000000000000000000]
# Processed 12 dataset eras
# [1111111111100000000000000000000000000000000]
# Processed 13 dataset eras
# [1111111111110000000000000000000000000000000]
# Processed 14 dataset eras
# [1111111111111000000000000000000000000000000]
# Processed 15 dataset eras
# [1111111111111100000000000000000000000000000]
# Processed 16 dataset eras
# [1111111111111110000000000000000000000000000]
# Processed 17 dataset eras
# [1111111111111111000000000000000000000000000]
# Processed 18 dataset eras
# [1111111111111111100000000000000000000000000]
# Processed 19 dataset eras
# [1111111111111111110000000000000000000000000]
# Processed 20 dataset eras
# [1111111111111111111000000000000000000000000]
# Processed 21 dataset eras
# [1111111111111111111100000000000000000000000]
# Processed 22 dataset eras
# [1111111111111111111110000000000000000000000]
# Processed 23 dataset eras
# [1111111111111111111111000000000000000000000]
# Processed 24 dataset eras
# [1111111111111111111111100000000000000000000]
# Processed 25 dataset eras
# [1111111111111111111111110000000000000000000]
# Processed 26 dataset eras
# [1111111111111111111111111000000000000000000]
# Processed 27 dataset eras
# [1111111111111111111111111100000000000000000]
# Processed 28 dataset eras
# [1111111111111111111111111110000000000000000]
# Processed 29 dataset eras
# [1111111111111111111111111111000000000000000]
# Processed 30 dataset eras
# [1111111111111111111111111111100000000000000]
# Processed 31 dataset eras
# [1111111111111111111111111111110000000000000]
# Processed 32 dataset eras
# [1111111111111111111111111111111000000000000]
# Processed 33 dataset eras
# [1111111111111111111111111111111100000000000]
# Processed 34 dataset eras
# [1111111111111111111111111111111110000000000]
# Processed 35 dataset eras
# [1111111111111111111111111111111111000000000]
# Processed 36 dataset eras
# [1111111111111111111111111111111111100000000]
# Processed 37 dataset eras
# [1111111111111111111111111111111111110000000]
# Processed 38 dataset eras
# [1111111111111111111111111111111111111000000]
# Processed 39 dataset eras
# [1111111111111111111111111111111111111100000]
# Processed 40 dataset eras
# [1111111111111111111111111111111111111110000]
# Processed 41 dataset eras
# [1111111111111111111111111111111111111111000]
# Processed 42 dataset eras
# [1111111111111111111111111111111111111111100]
# Processed 43 dataset eras
# [1111111111111111111111111111111111111111110]
# Processed 44 dataset eras
# [1111111111111111111111111111111111111111111]
# Processed 1 dataset eras
# [0000000000000000000000000000000000000000000]
# Processed 2 dataset eras
# [1000000000000000000000000000000000000000000]
# Processed 3 dataset eras
# [1100000000000000000000000000000000000000000]
# Processed 4 dataset eras
# [1110000000000000000000000000000000000000000]
# Processed 5 dataset eras
# [1111000000000000000000000000000000000000000]
# Processed 6 dataset eras
# [1111100000000000000000000000000000000000000]
# Processed 7 dataset eras
# [1111110000000000000000000000000000000000000]
# Processed 8 dataset eras
# [1111111000000000000000000000000000000000000]
# Processed 9 dataset eras
# [1111111100000000000000000000000000000000000]
# Processed 10 dataset eras
# [1111111110000000000000000000000000000000000]
# Processed 11 dataset eras
# [1111111111000000000000000000000000000000000]
# Processed 12 dataset eras
# [1111111111100000000000000000000000000000000]
# Processed 13 dataset eras
# [1111111111110000000000000000000000000000000]
# Processed 14 dataset eras
# [1111111111111000000000000000000000000000000]
# Processed 15 dataset eras
# [1111111111111100000000000000000000000000000]
# Processed 16 dataset eras
# [1111111111111110000000000000000000000000000]
# Processed 17 dataset eras
# [1111111111111111000000000000000000000000000]
# Processed 18 dataset eras
# [1111111111111111100000000000000000000000000]
# Processed 19 dataset eras
# [1111111111111111110000000000000000000000000]
# Processed 20 dataset eras
# [1111111111111111111000000000000000000000000]
# Processed 21 dataset eras
# [1111111111111111111100000000000000000000000]
# Processed 22 dataset eras
# [1111111111111111111110000000000000000000000]
# Processed 23 dataset eras
# [1111111111111111111111000000000000000000000]
# Processed 24 dataset eras
# [1111111111111111111111100000000000000000000]
# Processed 25 dataset eras
# [1111111111111111111111110000000000000000000]
# Processed 26 dataset eras
# [1111111111111111111111111000000000000000000]
# Processed 27 dataset eras
# [1111111111111111111111111100000000000000000]
# Processed 28 dataset eras
# [1111111111111111111111111110000000000000000]
# Processed 29 dataset eras
# [1111111111111111111111111111000000000000000]
# Processed 30 dataset eras
# [1111111111111111111111111111100000000000000]
# Processed 31 dataset eras
# [1111111111111111111111111111110000000000000]
# Processed 32 dataset eras
# [1111111111111111111111111111111000000000000]
# Processed 33 dataset eras
# [1111111111111111111111111111111100000000000]
# Processed 34 dataset eras
# [1111111111111111111111111111111110000000000]
# Processed 35 dataset eras
# [1111111111111111111111111111111111000000000]
# Processed 36 dataset eras
# [1111111111111111111111111111111111100000000]
# Processed 37 dataset eras
# [1111111111111111111111111111111111110000000]
# Processed 38 dataset eras
# [1111111111111111111111111111111111111000000]
# Processed 39 dataset eras
# [1111111111111111111111111111111111111100000]
# Processed 40 dataset eras
# [1111111111111111111111111111111111111110000]
# Processed 41 dataset eras
# [1111111111111111111111111111111111111111000]
# Processed 42 dataset eras
# [1111111111111111111111111111111111111111100]
# Processed 43 dataset eras
# [1111111111111111111111111111111111111111110]
# Processed 44 dataset eras
# [1111111111111111111111111111111111111111111]
# Processed 1 dataset eras
# [0000000000000000000000000000000000000000000]
# Processed 2 dataset eras
# [1000000000000000000000000000000000000000000]
# Processed 3 dataset eras
# [1100000000000000000000000000000000000000000]
# Processed 4 dataset eras
# [1110000000000000000000000000000000000000000]
# Processed 5 dataset eras
# [1111000000000000000000000000000000000000000]
# Processed 6 dataset eras
# [1111100000000000000000000000000000000000000]
# Processed 7 dataset eras
# [1111110000000000000000000000000000000000000]
# Processed 8 dataset eras
# [1111111000000000000000000000000000000000000]
# Processed 9 dataset eras
# [1111111100000000000000000000000000000000000]
# Processed 10 dataset eras
# [1111111110000000000000000000000000000000000]
# Processed 11 dataset eras
# [1111111111000000000000000000000000000000000]
# Processed 12 dataset eras
# [1111111111100000000000000000000000000000000]
# Processed 13 dataset eras
# [1111111111110000000000000000000000000000000]
# Processed 14 dataset eras
# [1111111111111000000000000000000000000000000]
# Processed 15 dataset eras
# [1111111111111100000000000000000000000000000]
# Processed 16 dataset eras
# [1111111111111110000000000000000000000000000]
# Processed 17 dataset eras
# [1111111111111111000000000000000000000000000]
# Processed 18 dataset eras
# [1111111111111111100000000000000000000000000]
# Processed 19 dataset eras
# [1111111111111111110000000000000000000000000]
# Processed 20 dataset eras
# [1111111111111111111000000000000000000000000]
# Processed 21 dataset eras
# [1111111111111111111100000000000000000000000]
# Processed 22 dataset eras
# [1111111111111111111110000000000000000000000]
# Processed 23 dataset eras
# [1111111111111111111111000000000000000000000]
# Processed 24 dataset eras
# [1111111111111111111111100000000000000000000]
# Processed 25 dataset eras
# [1111111111111111111111110000000000000000000]
# Processed 26 dataset eras
# [1111111111111111111111111000000000000000000]
# Processed 27 dataset eras
# [1111111111111111111111111100000000000000000]
# Processed 28 dataset eras
# [1111111111111111111111111110000000000000000]
# Processed 29 dataset eras
# [1111111111111111111111111111000000000000000]
# Processed 30 dataset eras
# [1111111111111111111111111111100000000000000]
# Processed 31 dataset eras
# [1111111111111111111111111111110000000000000]
# Processed 32 dataset eras
# [1111111111111111111111111111111000000000000]
# Processed 33 dataset eras
# [1111111111111111111111111111111100000000000]
# Processed 34 dataset eras
# [1111111111111111111111111111111110000000000]
# Processed 35 dataset eras
# [1111111111111111111111111111111111000000000]
# Processed 36 dataset eras
# [1111111111111111111111111111111111100000000]
# Processed 37 dataset eras
# [1111111111111111111111111111111111110000000]
# Processed 38 dataset eras
# [1111111111111111111111111111111111111000000]
# Processed 39 dataset eras
# [1111111111111111111111111111111111111100000]
# Processed 40 dataset eras
# [1111111111111111111111111111111111111110000]
# Processed 41 dataset eras
# [1111111111111111111111111111111111111111000]
# Processed 42 dataset eras
# [1111111111111111111111111111111111111111100]
# Processed 43 dataset eras
# [1111111111111111111111111111111111111111110]
# Processed 44 dataset eras
# [1111111111111111111111111111111111111111111]
# Processed 1 dataset eras
# [0000000000000000000000000000000000000000000]
# Processed 2 dataset eras
# [1000000000000000000000000000000000000000000]
# Processed 3 dataset eras
# [1100000000000000000000000000000000000000000]
# Processed 4 dataset eras
# [1110000000000000000000000000000000000000000]
# Processed 5 dataset eras
# [1111000000000000000000000000000000000000000]
# Processed 6 dataset eras
# [1111100000000000000000000000000000000000000]
# Processed 7 dataset eras
# [1111110000000000000000000000000000000000000]
# Processed 8 dataset eras
# [1111111000000000000000000000000000000000000]
# Processed 9 dataset eras
# [1111111100000000000000000000000000000000000]
# Processed 10 dataset eras
# [1111111110000000000000000000000000000000000]
# Processed 11 dataset eras
# [1111111111000000000000000000000000000000000]
# Processed 12 dataset eras
# [1111111111100000000000000000000000000000000]
# Processed 13 dataset eras
# [1111111111110000000000000000000000000000000]
# Processed 14 dataset eras
# [1111111111111000000000000000000000000000000]
# Processed 15 dataset eras
# [1111111111111100000000000000000000000000000]
# Processed 16 dataset eras
# [1111111111111110000000000000000000000000000]
# Processed 17 dataset eras
# [1111111111111111000000000000000000000000000]
# Processed 18 dataset eras
# [1111111111111111100000000000000000000000000]
# Processed 19 dataset eras
# [1111111111111111110000000000000000000000000]
# Processed 20 dataset eras
# [1111111111111111111000000000000000000000000]
# Processed 21 dataset eras
# [1111111111111111111100000000000000000000000]
# Processed 22 dataset eras
# [1111111111111111111110000000000000000000000]
# Processed 23 dataset eras
# [1111111111111111111111000000000000000000000]
# Processed 24 dataset eras
# [1111111111111111111111100000000000000000000]
# Processed 25 dataset eras
# [1111111111111111111111110000000000000000000]
# Processed 26 dataset eras
# [1111111111111111111111111000000000000000000]
# Processed 27 dataset eras
# [1111111111111111111111111100000000000000000]
# Processed 28 dataset eras
# [1111111111111111111111111110000000000000000]
# Processed 29 dataset eras
# [1111111111111111111111111111000000000000000]
# Processed 30 dataset eras
# [1111111111111111111111111111100000000000000]
# Processed 31 dataset eras
# [1111111111111111111111111111110000000000000]
# Processed 32 dataset eras
# [1111111111111111111111111111111000000000000]
# Processed 33 dataset eras
# [1111111111111111111111111111111100000000000]
# Processed 34 dataset eras
# [1111111111111111111111111111111110000000000]
# Processed 35 dataset eras
# [1111111111111111111111111111111111000000000]
# Processed 36 dataset eras
# [1111111111111111111111111111111111100000000]
# Processed 37 dataset eras
# [1111111111111111111111111111111111110000000]
# Processed 38 dataset eras
# [1111111111111111111111111111111111111000000]
# Processed 39 dataset eras
# [1111111111111111111111111111111111111100000]
# Processed 40 dataset eras
# [1111111111111111111111111111111111111110000]
# Processed 41 dataset eras
# [1111111111111111111111111111111111111111000]
# Processed 42 dataset eras
# [1111111111111111111111111111111111111111100]
# Processed 43 dataset eras
# [1111111111111111111111111111111111111111110]
# Processed 44 dataset eras
# [1111111111111111111111111111111111111111111]
# Processed 1 dataset eras
# [0000000000000000000000000000000000000000000]
# Processed 2 dataset eras
# [1000000000000000000000000000000000000000000]
# Processed 3 dataset eras
# [1100000000000000000000000000000000000000000]
# Processed 4 dataset eras
# [1110000000000000000000000000000000000000000]
# Processed 5 dataset eras
# [1111000000000000000000000000000000000000000]
# Processed 6 dataset eras
# [1111100000000000000000000000000000000000000]
# Processed 7 dataset eras
# [1111110000000000000000000000000000000000000]
# Processed 8 dataset eras
# [1111111000000000000000000000000000000000000]
# Processed 9 dataset eras
# [1111111100000000000000000000000000000000000]
# Processed 10 dataset eras
# [1111111110000000000000000000000000000000000]
# Processed 11 dataset eras
# [1111111111000000000000000000000000000000000]
# Processed 12 dataset eras
# [1111111111100000000000000000000000000000000]
# Processed 13 dataset eras
# [1111111111110000000000000000000000000000000]
# Processed 14 dataset eras
# [1111111111111000000000000000000000000000000]
# Processed 15 dataset eras
# [1111111111111100000000000000000000000000000]
# Processed 16 dataset eras
# [1111111111111110000000000000000000000000000]
# Processed 17 dataset eras
# [1111111111111111000000000000000000000000000]
# Processed 18 dataset eras
# [1111111111111111100000000000000000000000000]
# Processed 19 dataset eras
# [1111111111111111110000000000000000000000000]
# Processed 20 dataset eras
# [1111111111111111111000000000000000000000000]
# Processed 21 dataset eras
# [1111111111111111111100000000000000000000000]
# Processed 22 dataset eras
# [1111111111111111111110000000000000000000000]
# Processed 23 dataset eras
# [1111111111111111111111000000000000000000000]
# Processed 24 dataset eras
# [1111111111111111111111100000000000000000000]
# Processed 25 dataset eras
# [1111111111111111111111110000000000000000000]
# Processed 26 dataset eras
# [1111111111111111111111111000000000000000000]
# Processed 27 dataset eras
# [1111111111111111111111111100000000000000000]
# Processed 28 dataset eras
# [1111111111111111111111111110000000000000000]
# Processed 29 dataset eras
# [1111111111111111111111111111000000000000000]
# Processed 30 dataset eras
# [1111111111111111111111111111100000000000000]
# Processed 31 dataset eras
# [1111111111111111111111111111110000000000000]
# Processed 32 dataset eras
# [1111111111111111111111111111111000000000000]
# Processed 33 dataset eras
# [1111111111111111111111111111111100000000000]
# Processed 34 dataset eras
# [1111111111111111111111111111111110000000000]
# Processed 35 dataset eras
# [1111111111111111111111111111111111000000000]
# Processed 36 dataset eras
# [1111111111111111111111111111111111100000000]
# Processed 37 dataset eras
# [1111111111111111111111111111111111110000000]
# Processed 38 dataset eras
# [1111111111111111111111111111111111111000000]
# Processed 39 dataset eras
# [1111111111111111111111111111111111111100000]
# Processed 40 dataset eras
# [1111111111111111111111111111111111111110000]
# Processed 41 dataset eras
# [1111111111111111111111111111111111111111000]
# Processed 42 dataset eras
# [1111111111111111111111111111111111111111100]
# Processed 43 dataset eras
# [1111111111111111111111111111111111111111110]
# Processed 44 dataset eras
# [1111111111111111111111111111111111111111111]
# Processed 1 dataset eras
# [0000000000000000000000000000000000000000000]
# Processed 2 dataset eras
# [1000000000000000000000000000000000000000000]
# Processed 3 dataset eras
# [1100000000000000000000000000000000000000000]
# Processed 4 dataset eras
# [1110000000000000000000000000000000000000000]
# Processed 5 dataset eras
# [1111000000000000000000000000000000000000000]
# Processed 6 dataset eras
# [1111100000000000000000000000000000000000000]
# Processed 7 dataset eras
# [1111110000000000000000000000000000000000000]
# Processed 8 dataset eras
# [1111111000000000000000000000000000000000000]
# Processed 9 dataset eras
# [1111111100000000000000000000000000000000000]
# Processed 10 dataset eras
# [1111111110000000000000000000000000000000000]
# Processed 11 dataset eras
# [1111111111000000000000000000000000000000000]
# Processed 12 dataset eras
# [1111111111100000000000000000000000000000000]
# Processed 13 dataset eras
# [1111111111110000000000000000000000000000000]
# Processed 14 dataset eras
# [1111111111111000000000000000000000000000000]
# Processed 15 dataset eras
# [1111111111111100000000000000000000000000000]
# Processed 16 dataset eras
# [1111111111111110000000000000000000000000000]
# Processed 17 dataset eras
# [1111111111111111000000000000000000000000000]
# Processed 18 dataset eras
# [1111111111111111100000000000000000000000000]
# Processed 19 dataset eras
# [1111111111111111110000000000000000000000000]
# Processed 20 dataset eras
# [1111111111111111111000000000000000000000000]
# Processed 21 dataset eras
# [1111111111111111111100000000000000000000000]
# Processed 22 dataset eras
# [1111111111111111111110000000000000000000000]
# Processed 23 dataset eras
# [1111111111111111111111000000000000000000000]
# Processed 24 dataset eras
# [1111111111111111111111100000000000000000000]
# Processed 25 dataset eras
# [1111111111111111111111110000000000000000000]
# Processed 26 dataset eras
# [1111111111111111111111111000000000000000000]
# Processed 27 dataset eras
# [1111111111111111111111111100000000000000000]
# Processed 28 dataset eras
# [1111111111111111111111111110000000000000000]
# Processed 29 dataset eras
# [1111111111111111111111111111000000000000000]
# Processed 30 dataset eras
# [1111111111111111111111111111100000000000000]
# Processed 31 dataset eras
# [1111111111111111111111111111110000000000000]
# Processed 32 dataset eras
# [1111111111111111111111111111111000000000000]
# Processed 33 dataset eras
# [1111111111111111111111111111111100000000000]
# Processed 34 dataset eras
# [1111111111111111111111111111111110000000000]
# Processed 35 dataset eras
# [1111111111111111111111111111111111000000000]
# Processed 36 dataset eras
# [1111111111111111111111111111111111100000000]
# Processed 37 dataset eras
# [1111111111111111111111111111111111110000000]
# Processed 38 dataset eras
# [1111111111111111111111111111111111111000000]
# Processed 39 dataset eras
# [1111111111111111111111111111111111111100000]
# Processed 40 dataset eras
# [1111111111111111111111111111111111111110000]
# Processed 41 dataset eras
# [1111111111111111111111111111111111111111000]
# Processed 42 dataset eras
# [1111111111111111111111111111111111111111100]
# Processed 43 dataset eras
# [1111111111111111111111111111111111111111110]
# Processed 44 dataset eras
# [1111111111111111111111111111111111111111111]

# %% [markdown]
# ## April/May 2023 Update

# %%
years = range(1950, 2024)
months = ["April"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)

years = range(1950, 2024)
months = ["May"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)

years = range(1950, 2024)
months = ["April", "May"]
hours = [7, 10, 13, 16]
elevation_def = 1000
Table_Creation(years, months, hours, elevation_def)
# Out:
# PADK
# Processed 1 airport datasets
# CYAZ
# Processed 2 airport datasets
# KACV
# Processed 3 airport datasets
# PAHO
# Processed 4 airport datasets
# KLGB
# Processed 5 airport datasets
# KNUC
# Processed 6 airport datasets
# KNTD
# Processed 7 airport datasets
# KNZY
# Processed 8 airport datasets
# PACD
# Processed 9 airport datasets
# PANT
# Processed 10 airport datasets
# KMRY
# Processed 11 airport datasets
# KLAX
# Processed 12 airport datasets
# KAST
# Processed 13 airport datasets
# KSAN
# Processed 14 airport datasets
# KNSI
# Processed 15 airport datasets
# KSFO
# Processed 16 airport datasets
# KSIT
# Processed 17 airport datasets
# PYAK
# Processed 18 airport datasets
# KOAK
# Processed 19 airport datasets
# KOTH
# Processed 20 airport datasets
# PADQ
# Processed 21 airport datasets
# KVBG
# Processed 22 airport datasets
# PADK
# Processed 1 airport datasets
# CYAZ
# Processed 2 airport datasets
# KACV
# Processed 3 airport datasets
# PAHO
# Processed 4 airport datasets
# KLGB
# Processed 5 airport datasets
# KNUC
# Processed 6 airport datasets
# KNTD
# Processed 7 airport datasets
# KNZY
# Processed 8 airport datasets
# PACD
# Processed 9 airport datasets
# PANT
# Processed 10 airport datasets
# KMRY
# Processed 11 airport datasets
# KLAX
# Processed 12 airport datasets
# KAST
# Processed 13 airport datasets
# KSAN
# Processed 14 airport datasets
# KNSI
# Processed 15 airport datasets
# KSFO
# Processed 16 airport datasets
# KSIT
# Processed 17 airport datasets
# PYAK
# Processed 18 airport datasets
# KOAK
# Processed 19 airport datasets
# KOTH
# Processed 20 airport datasets
# PADQ
# Processed 21 airport datasets
# KVBG
# Processed 22 airport datasets
# PADK
# Processed 1 airport datasets
# CYAZ
# Processed 2 airport datasets
# KACV
# Processed 3 airport datasets
# PAHO
# Processed 4 airport datasets
# KLGB
# Processed 5 airport datasets
# KNUC
# Processed 6 airport datasets
# KNTD
# Processed 7 airport datasets
# KNZY
# Processed 8 airport datasets
# PACD
# Processed 9 airport datasets
# PANT
# Processed 10 airport datasets
# KMRY
# Processed 11 airport datasets
# KLAX
# Processed 12 airport datasets
# KAST
# Processed 13 airport datasets
# KSAN
# Processed 14 airport datasets
# KNSI
# Processed 15 airport datasets
# KSFO
# Processed 16 airport datasets
# KSIT
# Processed 17 airport datasets
# PYAK
# Processed 18 airport datasets
# KOAK
# Processed 19 airport datasets
# KOTH
# Processed 20 airport datasets
# PADQ
# Processed 21 airport datasets
# KVBG
# Processed 22 airport datasets
